# %%
import sys
print(sys.version)
# Out:
# 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\m9nsu\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\m9nsu\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\m9nsu\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\m9nsu\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\m9nsu\anaconda3\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\m9nsu\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize

text = "Natural Language Processing helps computers understand human language."

tokens = word_tokenize(text)
print("Tokens:", tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\m9nsu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\m9nsu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# Tokens: ['Natural', 'Language', 'Processing', 'helps', 'computers', 'understand', 'human', 'language', '.']

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
filtered = [w for w in tokens if w.lower() not in stop_words]

print("Original tokens:", tokens)
print("After stopword removal:", filtered)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\m9nsu\AppData\Roaming\nltk_data...
# Original tokens: ['Natural', 'Language', 'Processing', 'helps', 'computers', 'understand', 'human', 'language', '.']
# After stopword removal: ['Natural', 'Language', 'Processing', 'helps', 'computers', 'understand', 'human', 'language', '.']
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
text2 = "The student is learning Natural Language Processing at the university."
tokens2 = word_tokenize(text2)
filtered2 = [w for w in tokens2 if w.lower() not in stop_words]

print("Original:", tokens2)
print("After stopword removal:", filtered2)
# Out:
# Original: ['The', 'student', 'is', 'learning', 'Natural', 'Language', 'Processing', 'at', 'the', 'university', '.']
# After stopword removal: ['student', 'learning', 'Natural', 'Language', 'Processing', 'university', '.']
